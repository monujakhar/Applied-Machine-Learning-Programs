# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Custom Sigmoid Function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Generate Input Values
x = np.linspace(-10, 10, 200)

# Calculate Sigmoid Values
y = sigmoid(x)

# %%
# Display Sample Values
print("Sample Sigmoid Values")

for i in range(0, 200, 20):
    print(f"x = {x[i]:.2f}   Sigmoid(x) = {y[i]:.4f}")

# Plot Sigmoid Curve
plt.figure(figsize=(8,5))
plt.plot(x, y, linewidth=2)
plt.title("Logistic (Sigmoid) Function")
plt.xlabel("Input (x)")
plt.ylabel("Sigmoid(x)")
plt.grid(True)
plt.show()
# Out:
# Sample Sigmoid Values
# x = -10.00   Sigmoid(x) = 0.0000
# x = -7.99   Sigmoid(x) = 0.0003
# x = -5.98   Sigmoid(x) = 0.0025
# x = -3.97   Sigmoid(x) = 0.0185
# x = -1.96   Sigmoid(x) = 0.1235
# x = 0.05   Sigmoid(x) = 0.5126
# x = 2.06   Sigmoid(x) = 0.8870
# x = 4.07   Sigmoid(x) = 0.9832
# x = 6.08   Sigmoid(x) = 0.9977
# x = 8.09   Sigmoid(x) = 0.9997
